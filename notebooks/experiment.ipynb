# %% [markdown]
# # Phase 8 — Token experiment (naive vs graph)
#
# Re-run the two-arm comparison from the SDK. Requires `OPENAI_API_KEY` and a configured subject under `data/`. For CI-style checks without API spend, use the unit tests in `tests/unit/test_experiment.py` (mocked `run_investigation`).

# %%
from pathlib import Path

from graphdebug.sdk.api import BugTask, run_token_experiment

ROOT = Path.cwd().resolve()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent

bug = BugTask(
    target_root=str(ROOT / "data" / "pysnooper-bugsinpy-1"),
    failing_tests=("tests/test_chinese.py::test_chinese",),
    symptom="UnicodeEncodeError on non-ASCII trace output",
)

res = run_token_experiment(bug, project_root=ROOT, assume_hitl_ack=True)
print(res.report_path, res.chart_path, res.kpis)
